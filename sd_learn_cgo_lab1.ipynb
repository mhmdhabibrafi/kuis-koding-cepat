# %%
prompt_html = """
Buatkan saya kode HTML5 lengkap untuk sebuah game kuis. Di dalamnya harus ada:
1. Sebuah `div` utama dengan `id="game-container"`.
2. Di dalam kontainer, ada elemen `h2` dengan `id="question-text"` untuk menampilkan teks pertanyaan.
3. Di bawahnya, sebuah `div` dengan `id="answers-container"` yang akan menampung tombol-tombol jawaban.
4. Terakhir, sebuah elemen `h3` dengan `id="score-display"` untuk menunjukkan skor, awalnya berisi teks 'Skor: 0'.
Pastikan kode ini menyertakan link ke file 'style.css' dan 'script.js'.
"""

hasil_html = model.invoke(prompt_html)
print(hasil_html)

prompt_css = """
Buatkan saya kode CSS untuk file `style.css`.
- Untuk `body`, gunakan `background-color: #1a2b3c;`, `color: white;`, dan `font-family: sans-serif;`.
- Posisikan `#game-container` di tengah layar dengan `width: 80%`, `max-width: 600px`, `margin: 50px auto;`. Berikan `background-color: #2c3e50;`, `padding: 20px;`, dan `border-radius: 10px;`.
- Buat `#answers-container` menampilkan tombol secara vertikal.
- Untuk tombol di dalam `#answers-container`, buat tampilannya block penuh dengan `width: 100%`, `padding: 15px`, `margin: 5px 0`, `background-color: #4a6fa5;`, `border: none`, `color: white`, `cursor: pointer`, dan `font-size: 16px;`.
- Berikan efek hover yang mengubah `background-color` tombol menjadi `#6a8fb5`.
"""

hasil_css = model.invoke(prompt_css)
print(hasil_css)

prompt_js = """
Buatkan saya kode JavaScript lengkap untuk `script.js`. Kode ini harus melakukan hal-hal berikut secara berurutan:

1.  **Seleksi Elemen**: Buat variabel konstanta untuk menyeleksi elemen HTML dengan id `question-text`, `answers-container`, dan `score-display`.

2.  **Inisialisasi Variabel**: Buat variabel `skor` yang diawali dengan nilai 0 dan `pertanyaanIndex` yang diawali dengan 0.

3.  **Data Kuis**: Buat sebuah array bernama `daftarPertanyaan` yang berisi 5 objek pertanyaan pemrograman. Setiap objek harus memiliki properti: `pertanyaan` (string), `jawaban` (array berisi 4 string), dan `jawabanBenar` (string).

4.  **Fungsi `mulaiGame()`**: Buat fungsi ini untuk memulai atau mereset game dengan mengatur skor dan index ke 0, lalu memanggil `tampilkanPertanyaanBerikutnya()`.

5.  **Fungsi `tampilkanPertanyaanBerikutnya()`**: Fungsi ini harus membersihkan tombol jawaban sebelumnya, mengambil pertanyaan saat ini, menampilkannya, lalu membuat 4 tombol jawaban baru. Setiap tombol saat diklik harus memanggil fungsi `pilihJawaban()`.

6.  **Fungsi `pilihJawaban(jawabanTerpilih)`**: Fungsi ini memeriksa apakah jawaban yang dipilih benar. Jika benar, tambahkan 10 ke skor. Setelah itu, naikkan `pertanyaanIndex`. Jika masih ada pertanyaan, panggil `tampilkanPertanyaanBerikutnya()`. Jika tidak, tampilkan pesan 'Game Selesai! Skor Akhir Anda: [skor]'.

7.  **Menjalankan Game**: Terakhir, tambahkan satu baris kode di paling bawah untuk memanggil `mulaiGame()` agar game langsung berjalan saat script dimuat.
"""

hasil_js = model.invoke(prompt_js)
print(hasil_js)
# Out:
# Berikut adalah kode HTML5 yang Anda perminta untuk sebuah game kuis:
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Game Kuis</title>
#     <link rel="stylesheet" href="style.css">
# </head>
# <body>
#     <div id="game-container">
#         <h2 id="question-text"></h2>
#         <div id="answers-container">
#             <!-- Jawaban akan ditampilkan di sini oleh JavaScript -->
#         </div>
#         <h3 id="score-display">Skor: 0</h3>
#     </div>
#     <script src="script.js"></script>
# </body>
# </html>
# ```
#
# ### Penjelasan:
#
# 1. **Tag `<!DOCTYPE html>`**: Mendefinisikan versi HTML yang digunakan.
# 2. **Tag `<html lang="en">`**: Mendefinisikan dokument HTML sebagai dokumen dalam bahasa Inggris.
# 3. **Tag `<head>`**: Menerangkan informasi meta yang tidak dirender dan link ke file CSS.
# ...
